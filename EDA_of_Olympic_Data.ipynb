# %% [markdown]
# <a href="https://colab.research.google.com/github/Ceefour18/Ceefour18/blob/main/EDA_of_Olympic_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA with Olympic 2024 dataset**

# %%
#Install neccesary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Import data
data= ("/content/sample_data/Olympicdata.csv")
df= pd.read_csv(data)
df.head()
# Out:
#    Rank        Country Country Code  Gold  Silver  Bronze  Total
# 0     1  United States           US    40      44      42    126
# 1     2          China          CHN    40      27      24     91
# 2     3          Japan          JPN    20      12      13     45
# 3     4      Australia          AUS    18      19      16     53
# 4     5         France          FRA    16      26      22     64

# %%
df.tail()
# Out:
#     Rank    Country Country Code  Gold  Silver  Bronze  Total
# 86    84       Peru          PER     0       0       1      1
# 87    84      Qatar          QAT     0       0       1      1
# 88    84  Singapore          SIN     0       0       1      1
# 89    84   Slovakia          SVK     0       0       1      1
# 90    84     Zambia          ZAM     0       0       1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          91 non-null     int64
#  1   Country       91 non-null     object
#  2   Country Code  91 non-null     object
#  3   Gold          91 non-null     int64
#  4   Silver        91 non-null     int64
#  5   Bronze        91 non-null     int64
#  6   Total         91 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 5.1+ KB

# %%
df.describe()
# Out:
#             Rank       Gold     Silver     Bronze       Total
# count  91.000000  91.000000  91.000000  91.000000   91.000000
# mean   45.307692   3.604396   3.593407   4.219780   11.417582
# std    25.652244   6.990278   6.770816   6.558798   19.702829
# min     1.000000   0.000000   0.000000   0.000000    1.000000
# 25%    23.500000   0.000000   0.000000   1.000000    2.000000
# 50%    44.000000   1.000000   1.000000   2.000000    5.000000
# 75%    68.000000   3.000000   3.000000   5.000000    9.000000
# max    84.000000  40.000000  44.000000  42.000000  126.000000

# %%
df.isna().sum()
# Out:
# Rank            0
# Country         0
# Country Code    0
# Gold            0
# Silver          0
# Bronze          0
# Total           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 86    False
# 87    False
# 88    False
# 89    False
# 90    False
# Length: 91, dtype: bool

# %%
df.rename(columns={"Total":"Overall_count"}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           91 non-null     int64
#  1   Country        91 non-null     object
#  2   Country Code   91 non-null     object
#  3   Gold           91 non-null     int64
#  4   Silver         91 non-null     int64
#  5   Bronze         91 non-null     int64
#  6   Overall_count  91 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 5.1+ KB

# %%
df["Country"].nunique()
# Out:
# 91

# %%
df["Gold"].nunique()
# Out:
# 18

# %%
df["Gold"].skew()
# Out:
# 3.628193632497961

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.tail()
# Out:
#     Rank    Country Country Code  Gold  Silver  Bronze  Total
# 86    84       Peru          PER     0       0       1      1
# 87    84      Qatar          QAT     0       0       1      1
# 88    84  Singapore          SIN     0       0       1      1
# 89    84   Slovakia          SVK     0       0       1      1
# 90    84     Zambia          ZAM     0       0       1      1

# %%
# To determine how many bronze (label) by Singapore (postion)
df.at[88, "Bronze"]
# Out:
# 1

# %%
df.head()
# Out:
#    Rank        Country Country Code  Gold  Silver  Bronze  Overall_count
# 0     1  United States           US    40      44      42            126
# 1     2          China          CHN    40      27      24             91
# 2     3          Japan          JPN    20      12      13             45
# 3     4      Australia          AUS    18      19      16             53
# 4     5         France          FRA    16      26      22             64

# %%
df= df.drop("Overall_count", axis=1)

# %%
df.head()
# Out:
#    Rank        Country Country Code  Gold  Silver  Bronze
# 0     1  United States           US    40      44      42
# 1     2          China          CHN    40      27      24
# 2     3          Japan          JPN    20      12      13
# 3     4      Australia          AUS    18      19      16
# 4     5         France          FRA    16      26      22

# %%
df["Total"]= df["Gold"] + df ["Silver"] + df["Bronze"]

# %%
df.head()
# Out:
#    Rank        Country Country Code  Gold  Silver  Bronze  Total
# 0     1  United States           US    40      44      42    126
# 1     2          China          CHN    40      27      24     91
# 2     3          Japan          JPN    20      12      13     45
# 3     4      Australia          AUS    18      19      16     53
# 4     5         France          FRA    16      26      22     64

# %%
import matplotlib.pyplot as plt
df.plot(kind="scatter", x="Gold", y="Silver")
plt.title("Scatter plot of Correlation between NUmber of Gold and Silver")
plt.ylabel("Number of Silver")
plt.ylabel("Number of Gold")
plt.show()
